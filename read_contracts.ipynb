# %%
import os
import pandas as pd

# %%
def read_contracts(folder):
    contracts = []
    files = []
    for file in os.listdir(folder):
        fullpath = folder + '/' + file
        with open(fullpath) as f:
            contracts.append(f.read())
            files.append(file)
    return files, contracts

# %%
ls
# Out:
# NLPmodel.ipynb        local_data/           transformers.ipynb
# README.md             nlp.code-workspace    transformers.pyc
# __pycache__/          tf.py                 transformers_test.py
# data/                 torchtest.py

# %%
folder = 'data/full_contract_txt'
files, contracts = read_contracts(folder)

# %%
contracts[0]
# Out:
# 'EXHIBIT 10.6\n\n                              DISTRIBUTOR AGREEMENT\n\n         THIS  DISTRIBUTOR  AGREEMENT (the  "Agreement")  is made by and between Electric City Corp.,  a Delaware  corporation  ("Company")  and Electric City of Illinois LLC ("Distributor") this 7th day of September, 1999.\n\n                                    RECITALS\n\n         A. The  Company\'s  Business.  The Company is  presently  engaged in the business  of selling an energy  efficiency  device,  which is  referred to as an "Energy  Saver"  which may be improved  or  otherwise  changed  from its present composition (the "Products").  The Company may engage in the business of selling other  products  or  other  devices  other  than  the  Products,  which  will be considered  Products if Distributor  exercises its options pursuant to Section 7 hereof.\n\n         B. Representations.  As an inducement to the Company to enter into this Agreement,  the  Distributor  has  represented  that  it has or  will  h
# ...

# %%
def read_text(filename):
    with open(filename) as f:
        text = f.read()
    return text

# %%
file = folder + '/' + files[0]

# %%
text = read_text(file)

# %%
text
# Out:
# 'EXHIBIT 10.6\n\n                              DISTRIBUTOR AGREEMENT\n\n         THIS  DISTRIBUTOR  AGREEMENT (the  "Agreement")  is made by and between Electric City Corp.,  a Delaware  corporation  ("Company")  and Electric City of Illinois LLC ("Distributor") this 7th day of September, 1999.\n\n                                    RECITALS\n\n         A. The  Company\'s  Business.  The Company is  presently  engaged in the business  of selling an energy  efficiency  device,  which is  referred to as an "Energy  Saver"  which may be improved  or  otherwise  changed  from its present composition (the "Products").  The Company may engage in the business of selling other  products  or  other  devices  other  than  the  Products,  which  will be considered  Products if Distributor  exercises its options pursuant to Section 7 hereof.\n\n         B. Representations.  As an inducement to the Company to enter into this Agreement,  the  Distributor  has  represented  that  it has or  will  h
# ...

# %%
ner = [{'entity_group': 'ORG', 'score': 0.9993481, 'word': 'Arkansas Western Pipeline Company', 'start': 210, 'end': 243}, {'entity_group': 'ORG', 'score': 0.99621093, 'word': 'Transporter', 'start': 246, 'end': 257}, {'entity_group': 'LOC', 'score': 0.99920774, 'word': 'Arkansas', 'start': 264, 'end': 272}, {'entity_group': 'ORG', 'score': 0.9994322, 'word': 'Associated Natural Gas Company', 'start': 290, 'end': 320}, {'entity_group': 'ORG', 'score': 0.9992976, 'word': 'Arkansas Western Gas Company', 'start': 336, 'end': 364}, {'entity_group': 'ORG', 'score': 0.98268515, 'word': 'Shipper', 'start': 368, 'end': 375}, {'entity_group': 'ORG', 'score': 0.8134537, 'word': 'Shipper', 'start': 445, 'end': 452}, {'entity_group': 'ORG', 'score': 0.74479127, 'word': 'Transporter', 'start': 488, 'end': 499}, {'entity_group': 'ORG', 'score': 0.71144277, 'word': 'Ship', 'start': 510, 'end': 514}, {'entity_group': 'ORG', 'score': 0.9789148, 'word': 'Transporter', 'start': 542, 'end': 553}, {'entity_group': 'ORG', 'score': 0.7350366, 'word': 'Shipper', 'start': 600, 'end': 607}, {'entity_group': 'MISC', 'score': 0.6672191, 'word': 'Agreement', 'start': 662, 'end': 671}]

# %%
ner
# Out:
# [{'entity_group': 'ORG',
#   'score': 0.9993481,
#   'word': 'Arkansas Western Pipeline Company',
#   'start': 210,
#   'end': 243},
#  {'entity_group': 'ORG',
#   'score': 0.99621093,
#   'word': 'Transporter',
#   'start': 246,
#   'end': 257},
#  {'entity_group': 'LOC',
#   'score': 0.99920774,
#   'word': 'Arkansas',
#   'start': 264,
#   'end': 272},
#  {'entity_group': 'ORG',
#   'score': 0.9994322,
#   'word': 'Associated Natural Gas Company',
#   'start': 290,
#   'end': 320},
#  {'entity_group': 'ORG',
#   'score': 0.9992976,
#   'word': 'Arkansas Western Gas Company',
#   'start': 336,
#   'end': 364},
#  {'entity_group': 'ORG',
#   'score': 0.98268515,
#   'word': 'Shipper',
#   'start': 368,
#   'end': 375},
#  {'entity_group': 'ORG',
#   'score': 0.8134537,
#   'word': 'Shipper',
#   'start': 445,
#   'end': 452},
#  {'entity_group': 'ORG',
#   'score': 0.74479127,
#   'word': 'Transporter',
#   'start': 488,
#   'end': 499},
#  {'entity_group': 'ORG',
# ...

# %%
def ner_categories(ner):
    df = pd.DataFrame(ner)
    df.drop(['start','end'], axis=1, inplace=True)
    df.sort_values('score', ascending=False)
    return df

# %%
df = ner_categories(ner)
df
# Out:
#    entity_group     score                               word
# 0           ORG  0.999348  Arkansas Western Pipeline Company
# 1           ORG  0.996211                        Transporter
# 2           LOC  0.999208                           Arkansas
# 3           ORG  0.999432     Associated Natural Gas Company
# 4           ORG  0.999298       Arkansas Western Gas Company
# 5           ORG  0.982685                            Shipper
# 6           ORG  0.813454                            Shipper
# 7           ORG  0.744791                        Transporter
# 8           ORG  0.711443                               Ship
# 9           ORG  0.978915                        Transporter
# 10          ORG  0.735037                            Shipper
# 11         MISC  0.667219                          Agreement
